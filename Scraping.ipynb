# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("vader_lexicon")
import pandas as pd
data = pd.read_csv("try.csv", encoding= 'unicode_escape')
data = data.dropna()
print(data.head())
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                     product_name product_price  Rate  \
# 0  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 1  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 2  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 3  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 4  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
#
#                                               Review  \
# 0                                          Just wow!
# 1                                          Fabulous!
# 2  Mind blowing Machine with all in(Mixing, Chopp...
# 3                                        Wow product
# 4                                      Super awesome
#
#                                              Summary
# 0  I had been thinking of purchasing a food proce...
# 1  Well,i bought this food processor for my Mom a...
# 2  Hello Flipkart users, i am using this product ...
# 3  Excellent product and excellent service provid...
# 4  This is super awesome food processor to make y...

# %%
sentiments = SentimentIntensityAnalyzer()
data["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data["Review"]]
data["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data["Review"]]
data["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data["Review"]]
data['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data["Review"]]
data.head()
# Out:
#                                     product_name product_price  Rate  \
# 0  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 1  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 2  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 3  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 4  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
#
#                                               Review  \
# 0                                          Just wow!
# 1                                          Fabulous!
# 2  Mind blowing Machine with all in(Mixing, Chopp...
# 3                                        Wow product
# 4                                      Super awesome
#
#                                              Summary  Positive  Negative  \
# 0  I had been thinking of purchasing a food proce...     0.804       0.0
# 1  Well,i bought this food processor for my Mom a...     1.000       0.0
# 2  Hello Flipkart users, i am using this product ...     0.000       0.0
# 3  Excellent product and excellent service provid...     0.792       0.0
# 4  This is super awesome food processor to make y...     1.000       0.0
#
#    Neutral  Compound
# 0    0.196    0.6239
# 1    0.000    0.5707
# 2    1.000    0.0000
# 3    0.208    0.5859
# 4    0.000    0.8402

# %%
score = data["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data["Sentiment"] = sentiment
data.head()
# Out:
#                                     product_name product_price  Rate  \
# 0  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 1  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 2  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 3  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 4  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
#
#                                               Review  \
# 0                                          Just wow!
# 1                                          Fabulous!
# 2  Mind blowing Machine with all in(Mixing, Chopp...
# 3                                        Wow product
# 4                                      Super awesome
#
#                                              Summary  Positive  Negative  \
# 0  I had been thinking of purchasing a food proce...     0.804       0.0
# 1  Well,i bought this food processor for my Mom a...     1.000       0.0
# 2  Hello Flipkart users, i am using this product ...     0.000       0.0
# 3  Excellent product and excellent service provid...     0.792       0.0
# 4  This is super awesome food processor to make y...     1.000       0.0
#
#    Neutral  Compound Sentiment
# 0    0.196    0.6239  Positive
# 1    0.000    0.5707  Positive
# 2    1.000    0.0000   Neutral
# 3    0.208    0.5859  Positive
# 4    0.000    0.8402  Positive

# %%
print(data["Sentiment"].value_counts())
# Out:
# Positive    10
# Neutral      5
# Negative     4
# Name: Sentiment, dtype: int64

# %%
data.to_csv("new_data.csv")

# %%
data.drop(data.columns[[5, 6, 7, 8]], axis=1, inplace=True)
data
# Out:
#                                      product_name product_price  Rate  \
# 0   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 1   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 2   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 3   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 4   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
# 5   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     3
# 6   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     1
# 7   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     3
# 8   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
# 9   Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
# 10  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
# 11  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
# 12  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 13  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
# 14  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     1
# 15  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     1
# 16  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     4
# 17  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     5
# 18  Inalsa fiesta 650 W Food Processor?ÿ?ÿ(White)      ??5,390     1
#
#                                                Review  \
# 0                                           Just wow!
# 1                                           Fabulous!
# 2   Mind blowing Machine with all in(Mixing, Chopp...
# 3                                         Wow product
# 4                                       Super awesome
# 5   Mixing, Grinding, chopping FANTASTIC. Shreddin...
# 6                                      Unsatisfactory
# 7                                           Just okay
# 8                                     Value-for-money
# 9                                     Value-for-money
# 10                                        Pretty good
# 11                                        Good choice
# 12                                 Highly recommended
# 13                  One of the best Kitchen Appliance
# 14                             Worst experience ever!
# 15                                    Waste of money!
# 16                                    Value-for-money
# 17                                      Great product
# 18                                          Worthless
#
#                                               Summary Sentiment
# 0   I had been thinking of purchasing a food proce...  Positive
# 1   Well,i bought this food processor for my Mom a...  Positive
# 2   Hello Flipkart users, i am using this product ...   Neutral
# 3   Excellent product and excellent service provid...  Positive
# 4   This is super awesome food processor to make y...  Positive
# 5   The product is decent in it`s price range all ...  Negative
# 6   Don't buy . previous quality of this product w...   Neutral
# 7   prodect same part good same part quality not g...  Positive
# 8   Product build quality can be improved rest won...   Neutral
# 9   After using for a month I am in love with this...   Neutral
# 10  This food processor is really awesome , it hel...  Positive
# 11  I am using this awesome product from almost 15...  Positive
# 12  I purchased this item on 18-10-2017, after 6 m...  Positive
# 13  I bought this product in 3400/- on BBD sale wh...  Positive
# 14  purchased just before 10days and motor not wor...  Negative
# 15  Due to low blade quality the cutting of spices...  Negative
# 16  Great Useful Product at Affordable Price.Must ...   Neutral
# 17                                       Good product  Positive
# 18  Product received looks like lying dead for lon...  Negative
